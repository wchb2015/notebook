# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
import seaborn as sns

# %%
a = [1,2,3]
plt.plot(a)

# %%
# %timeit np.arange(10)
# Out:
# 202 ns ± 4.95 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import pandas_datareader.data as web
import yfinance as yf
from datetime import datetime

# %%
tqqq = yf.Ticker("^IXIC")

# get all stock info

# get historical market data
tqqq = tqqq.history(period="12mo")

# %%
tqqq.tail()
# Out:
#                                    Open          High           Low  \
# Date
# 2024-01-10 00:00:00-05:00  14877.700195  14998.200195  14842.700195
# 2024-01-11 00:00:00-05:00  15020.950195  15063.610352  14800.379883
# 2024-01-12 00:00:00-05:00  15001.009766  15047.250000  14931.879883
# 2024-01-16 00:00:00-05:00  14908.259766  15004.349609  14863.809570
# 2024-01-17 00:00:00-05:00  14814.799805  14865.755859  14706.234375
#
#                                   Close      Volume  Dividends  Stock Splits
# Date
# 2024-01-10 00:00:00-05:00  14969.650391  4404590000        0.0           0.0
# 2024-01-11 00:00:00-05:00  14970.190430  5044690000        0.0           0.0
# 2024-01-12 00:00:00-05:00  14972.759766  4958940000        0.0           0.0
# 2024-01-16 00:00:00-05:00  14944.349609  6386180000        0.0           0.0
# 2024-01-17 00:00:00-05:00  14855.622070  4677322000        0.0           0.0

# %%
tqqq.shape
# Out:
# (251, 7)

# %%
tqqq['Volume'].plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %%
tqqq['High-Low'] = tqqq['High']-tqqq['Low']

# %%
tqqq['High-Low'].plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %%
tqqq.tail()
# Out:
#                                    Open          High           Low  \
# Date
# 2024-01-10 00:00:00-05:00  14877.700195  14998.200195  14842.700195
# 2024-01-11 00:00:00-05:00  15020.950195  15063.610352  14800.379883
# 2024-01-12 00:00:00-05:00  15001.009766  15047.250000  14931.879883
# 2024-01-16 00:00:00-05:00  14908.259766  15004.349609  14863.809570
# 2024-01-17 00:00:00-05:00  14814.799805  14865.755859  14706.234375
#
#                                   Close      Volume  Dividends  Stock Splits  \
# Date
# 2024-01-10 00:00:00-05:00  14969.650391  4404590000        0.0           0.0
# 2024-01-11 00:00:00-05:00  14970.190430  5044690000        0.0           0.0
# 2024-01-12 00:00:00-05:00  14972.759766  4958940000        0.0           0.0
# 2024-01-16 00:00:00-05:00  14944.349609  6386180000        0.0           0.0
# 2024-01-17 00:00:00-05:00  14855.622070  4677322000        0.0           0.0
#
#                              High-Low
# Date
# ...

# %%
tqqq['Close'].tail(20).pct_change().plot(legend=True,figsize=(15,5),linestyle='--',marker='o')
# Out:
# <Axes: xlabel='Date'>

# %%
tqqq['High-Low'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(tqqq['High-Low'],bins=100,color='purple')
# Out:
# /Users/chongbei/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
start = datetime(2023,1,1)
company = ['^IXIC','TQQQ','TSLA']

# %%
tickers = yf.Tickers(company)

# %%
tickers.tickers['TQQQ'].history(period="1mo")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-12-18 00:00:00-05:00  49.273692  50.378837  49.154214  50.050282
# 2023-12-19 00:00:00-05:00  50.199621  50.836827  50.139886  50.797001
# 2023-12-20 00:00:00-05:00  50.480000  51.270000  48.459999  48.540001
# 2023-12-21 00:00:00-05:00  49.889999  50.270000  48.939999  50.150002
# 2023-12-22 00:00:00-05:00  50.599998  50.939999  49.639999  50.349998
# 2023-12-26 00:00:00-05:00  50.639999  51.509998  50.619999  51.270000
# 2023-12-27 00:00:00-05:00  51.349998  51.660000  51.020000  51.540001
# 2023-12-28 00:00:00-05:00  51.919998  52.009998  51.270000  51.410000
# 2023-12-29 00:00:00-05:00  51.380001  51.520000  50.000000  50.700001
# 2024-01-02 00:00:00-05:00  49.349998  49.430000  47.270000  48.130001
# 2024-01-03 00:00:00-05:00  47.169998  47.540001  46.430000  46.590000
# 2024-01-04 00:00:00-05:00  45.869999  46.970001  45.730000  45.810001
# ...

# %%
pd.read_parquet("/Users/chongbei/Downloads/mobr.parquet").info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18349 entries, 0 to 18348
# Data columns (total 34 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   marketplace_id                        18349 non-null  int32
#  1   campaign_id                           18349 non-null  int64
#  2   metric_dates                          18349 non-null  object
#  3   estimated_spend_distr_sorted_by_date  18349 non-null  object
#  4   estimated_full_day_spend_mean         18349 non-null  float64
#  5   realized_spend_sorted_by_date         18349 non-null  object
#  6   mo_impressions                        18349 non-null  int64
#  7   mo_clicks                             18349 non-null  int64
#  8   mo_sales                              18349 non-null  float64
#  9   mo_spend                              18349 non-null  float64
#  10  sum_realized_spend                    18349 non-null  float64
# ...
