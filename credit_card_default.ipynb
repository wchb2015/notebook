# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing

# %%
df = pd.read_csv('/Users/chongbei/Workspace/personal/notebook/kaggle/data/credit_card_default.csv')

# %%
df.head(5)
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.shape
# Out:
# (30000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
#df.describe()
df.describe().T
# Out:
#                               count           mean            std       min  \
# LIMIT_BAL                   30000.0  167484.322667  129747.661567   10000.0
# SEX                         30000.0       1.603733       0.489129       1.0
# EDUCATION                   30000.0       1.853133       0.790349       0.0
# MARRIAGE                    30000.0       1.551867       0.521970       0.0
# AGE                         30000.0      35.485500       9.217904      21.0
# PAY_0                       30000.0      -0.016700       1.123802      -2.0
# PAY_2                       30000.0      -0.133767       1.197186      -2.0
# PAY_3                       30000.0      -0.166200       1.196868      -2.0
# PAY_4                       30000.0      -0.220667       1.169139      -2.0
# PAY_5                       30000.0      -0.266200       1.133187      -2.0
# PAY_6                       30000.0      -0.291100       1.149988      -2.0
# ...

# %%
df['SEX'].value_counts()
# Out:
# SEX
# 1    18112
# 0    11888
# Name: count, dtype: int64

# %%
df['SEX'].replace([1, 2], [0, 1], inplace=True)

# %%
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    15964
# 1    13659
# 0      377
# Name: count, dtype: int64

# %%
df['MARRIAGE'].replace(3, 0, inplace=True)

# %%
df['PAY_0'].value_counts()
# Out:
# PAY_0
# 0    23182
# 1     3688
# 2     2667
# 3      322
# 4       76
# 5       26
# 8       19
# 6       11
# 7        9
# Name: count, dtype: int64

# %%
df.iloc[:,
        [5, 6, 7, 8, 9, 10]] = df.iloc[:,
                                       [5, 6, 7, 8, 9, 10]].replace([-2, -1],
                                                                    [0, 0])
df.iloc[:, [5, 6, 7, 8, 9, 10]].describe()
# Out:
#               PAY_0         PAY_2         PAY_3         PAY_4        PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.00000
# mean       0.356767      0.320033      0.304067      0.258767      0.22150
# std        0.760594      0.801727      0.790589      0.761113      0.71772
# min        0.000000      0.000000      0.000000      0.000000      0.00000
# 25%        0.000000      0.000000      0.000000      0.000000      0.00000
# 50%        0.000000      0.000000      0.000000      0.000000      0.00000
# 75%        0.000000      0.000000      0.000000      0.000000      0.00000
# max        8.000000      8.000000      8.000000      8.000000      8.00000
#
#               PAY_6
# count  30000.000000
# mean       0.226567
# std        0.715438
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
df['default payment next month'].value_counts()[0]/df['default payment next month'].value_counts()[1]
# Out:
# 3.5207956600361663

# %%
plt.title('Credit Distribution ')
sns.set_color_codes("pastel")
sns.displot(df['LIMIT_BAL'],kde=True,bins=100,color="blue")
plt.xlabel("credits")
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...

# %%
plt.title('Age Distribution ')
sns.set_color_codes("pastel")
sns.displot(df['AGE'],kde=True,bins=100,color="green")
plt.xlabel("AGE")
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...

# %%
df['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: count, dtype: int64

# %%
fig = plt.subplots(1, 3, figsize=(16, 12))

plt.subplot(1, 3, 1)
sex_count = df['SEX'].value_counts()
sex_count.plot(kind='pie', labels=['Girl', 'Boy'], autopct='%1.1f%%')
plt.ylabel("")
plt.title('Sex Distribution')

plt.subplot(1, 3, 2)
edu_count = df['EDUCATION'].value_counts()
edu_count.plot(
    kind='pie',
    labels=['Bachelor', 'Master', 'Highschool', 'Other', 'A', 'B', 'C', 'D'],
    autopct='%1.1f%%')
plt.title('EDUCATION Distribution')
plt.ylabel("")

plt.subplot(1, 3, 3)
marriage_count = df['MARRIAGE'].value_counts()
marriage_count.plot(kind='pie',
                    labels=['Marriaged', 'Single', 'Other'],
                    autopct='%1.1f%%')
plt.title('MARRIAGE Distribution')
plt.ylabel("")

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...
